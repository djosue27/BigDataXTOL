# %%
import pandas as pd

# %%
credit = pd.read_csv("/Users/djosue27/OneDrive/Big Data XTOL/Module 5/Task 1/default of credit card clients.csv", header=1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null object
# EDUCATION                     30000 non-null object
# MARRIAGE                      30000 non-null object
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# ...

# %%
del credit['ID']

# %%
import matplotlib.pyplot as plt

# %%
header = credit.dtypes.index

# %%
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
# Out:
# (array([1.2498e+04, 7.8800e+03, 5.0590e+03, 2.7590e+03, 1.5980e+03,
#         1.2700e+02, 5.6000e+01, 2.2000e+01, 0.0000e+00, 1.0000e+00]),
#  array([  10000.,  109000.,  208000.,  307000.,  406000.,  505000.,
#          604000.,  703000.,  802000.,  901000., 1000000.]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(credit['LIMIT_BAL'])

# %%
for col in credit.columns:
    if credit[col].dtype == "object":
        # If categorical, do a count bar plot
        lm = pd.value_counts(credit[col]).plot.bar()
        lm.set_xticklabels(lm.get_xticklabels(),rotation=0)
        plt.title(col)
        plt.show()

    else:
        # If numerical, do a histogram
        credit.hist(column=col, bins=100)
        plt.title(col)
        plt.show()

# %%
credit = credit.replace({'SEX': {1: 'MALE',2: 'FEMALE'}})

# %%
credit = credit.replace({'EDUCATION': {1: 'GRADUATE SCHOOL',2: 'UNIVERSITY',3:'HIGH SCHOOL',0:'OTHERS',4:'OTHERS',5:'OTHERS',6:'OTHERS'}})

# %%
credit.head()
# Out:
#    LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000  FEMALE  UNIVERSITY         1   24      2      2     -1     -1
# 1     120000  FEMALE  UNIVERSITY         2   26     -1      2      0      0
# 2      90000  FEMALE  UNIVERSITY         2   34      0      0      0      0
# 3      50000  FEMALE  UNIVERSITY         1   37      0      0      0      0
# 4      50000    MALE  UNIVERSITY         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
# ...

# %%
credit = credit.replace({'MARRIAGE': {1: 'MARRIED',2: 'SINGLE',3: 'DIVORCE',0: 'OTHERS'}})

# %%
for col in credit.columns:
    if credit[col].dtype == "object":
        # If categorical, do a count bar plot
        lm = pd.value_counts(credit[col]).plot.bar()
        lm.set_xticklabels(lm.get_xticklabels(),rotation=0)
        plt.title(col)
        plt.show()

    else:
        # If numerical, do a histogram
        credit.hist(column=col, bins=100)
        plt.title(col)
        plt.show()

# %%
x = credit['SEX']
y = credit['LIMIT_BAL']

# %%
plt.hist(y)
# Out:
# (array([1.2498e+04, 7.8800e+03, 5.0590e+03, 2.7590e+03, 1.5980e+03,
#         1.2700e+02, 5.6000e+01, 2.2000e+01, 0.0000e+00, 1.0000e+00]),
#  array([  10000.,  109000.,  208000.,  307000.,  406000.,  505000.,
#          604000.,  703000.,  802000.,  901000., 1000000.]),
#  <a list of 10 Patch objects>)

# %%
plt.show()

# %%
header = credit.dtypes.index

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x119c3aeb8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x11c28dc88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x119c3a588>],
#  'medians': [<matplotlib.lines.Line2D at 0x11c28deb8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11c28d240>],
#  'means': []}

# %%
corrMat = credit.corr()

# %%
print(corrMat)
# Out:
#                             LIMIT_BAL       AGE     PAY_0     PAY_2     PAY_3  \
# LIMIT_BAL                    1.000000  0.144713 -0.271214 -0.296382 -0.286123
# AGE                          0.144713  1.000000 -0.039447 -0.050148 -0.053048
# PAY_0                       -0.271214 -0.039447  1.000000  0.672164  0.574245
# PAY_2                       -0.296382 -0.050148  0.672164  1.000000  0.766552
# PAY_3                       -0.286123 -0.053048  0.574245  0.766552  1.000000
# PAY_4                       -0.267460 -0.049722  0.538841  0.662067  0.777359
# PAY_5                       -0.249411 -0.053826  0.509426  0.622780  0.686775
# PAY_6                       -0.235195 -0.048773  0.474553  0.575501  0.632684
# BILL_AMT1                    0.285430  0.056239  0.187068  0.234887  0.208473
# BILL_AMT2                    0.278314  0.054283  0.189859  0.235257  0.237295
# BILL_AMT3                    0.283236  0.053710  0.179785  0.224146  0.227494
# ...

# %%
covMat = credit.cov()

# %%
print(covMat)
# Out:
#                                LIMIT_BAL            AGE         PAY_0  \
# LIMIT_BAL                   1.683446e+10  173076.722569 -39545.930009
# AGE                         1.730767e+05      84.969755     -0.408639
# PAY_0                      -3.954593e+04      -0.408639      1.262930
# PAY_2                      -4.603765e+04      -0.553408      0.904330
# PAY_3                      -4.443225e+04      -0.585263      0.772384
# PAY_4                      -4.057181e+04      -0.535851      0.707972
# PAY_5                      -3.667056e+04      -0.562245      0.648743
# PAY_6                      -3.509308e+04      -0.517022      0.613292
# BILL_AMT1                   2.727020e+09   38172.933546  15480.304170
# BILL_AMT2                   2.570130e+09   35613.657962  15185.916919
# BILL_AMT3                   2.548533e+09   34334.251320  14011.556537
# BILL_AMT4                   2.453926e+09   30453.108180  12950.248389
# ...

# %%
import seaborn as sns

# %%
import numpy as np

# %%
for col in credit.columns:
    if col == "default payment next month":
        continue
    
    if credit[col].dtype == "object":
        # If categorical, do a bar plot of counts
        lm = sns.barplot(data=credit, x=col, y="default payment next month")
        lm.set_xticklabels(lm.get_xticklabels(),rotation=30)
        plt.title("Default vs. {}".format(col))
        plt.show()
